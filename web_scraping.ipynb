# %% [markdown]
# <a href="https://colab.research.google.com/github/Brenoxx27/Breno/blob/main/web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

from bs4 import BeautifulSoup

# %%
import requests

from bs4 import BeautifulSoup

lista_de_produtos = []

numero_de_paginas = 1

headers = {'user-agent': 'mozilla/5.0'}

url = 'https://sp.olx.com.br/?q=iphone'

while numero_de_paginas > 0:

  url_ = requests.get(f'https://sp.olx.com.br/?o={numero_de_paginas}&q=iphone', headers=headers)

  site = BeautifulSoup(url_.text, 'html.parser')

  produtos = site.findAll('li', attrs={'class':'sc-1fcmfeb-2 fvbmlV'})

  for produto in produtos:
    try:

      nome = produto.find('h2', attrs={'class':'kgl1mq-0 eFXRHn sc-ifAKCX gzAEjc'})
      preco = produto.find('span', attrs={'class':'m7nrfa-0 eJCbzj sc-ifAKCX ANnoQ'})
      lugar = produto.find('span', attrs={'class':'sc-1c3ysll-1 cLQXSQ sc-ifAKCX fCbscF'})
      data = produto.find('span', attrs={'class':'sc-11h4wdr-0 javKJU sc-ifAKCX fCbscF'})


      try:
        link = produto.find('a', attrs={'sc-12rk7z2-1 huFwya sc-htoDjs fpYhGm'})['href']

      except: 
        link(' ')

      print(nome.text)
      print(preco.text)
      print(lugar.text)
      print(data.text)
      print(link)

      dicionario = {
          'TITULO DO PRODUTO: ', nome.text,
          'PREÇO DO PRODUTO: ', preco.text,
          'LUGAR DO VENDEDOR: ', lugar.text,
          'DATA DA POSTAGEM: ', data.text,
          'LINK DO PRODUTO: ', link
      }
      lista_de_produtos.append(dicionario)

      print(' ')

    except: ' '
numero_de_paginas += 1
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# https://sp.olx.com.br/grande-campinas/celulares/iphone-7-plus-preto-128-gb-aceito-tv-1102080827
#
# iPhone 11 128 gb
# R$ 3.000
# Americana, Brieds - DDD 19
# Hoje, 22:32
# https://sp.olx.com.br/grande-campinas/celulares/iphone-11-128-gb-1098552661
#
# iPhone SE 2020 64GB branco conservado
# R$ 1.350
# São Joaquim da Barra - DDD 16
# Hoje, 22:32
# https://sp.olx.com.br/regiao-de-ribeirao-preto/celulares/iphone-se-2020-64gb-branco-conservado-1105085267
#
# iPhone 12 Pro Max
# R$ 1.800
# Praia Grande, Mirim - DDD 13
# Hoje, 22:32
# https://sp.olx.com.br/baixada-santista-e-litoral-sul/celulares/iphone-12-pro-max-1106003863
#
# iPhone 11 128 gb novo lacrado
# R$ 3.700
# Jacareí, Santa Cruz dos Lázaros - DDD 12
# Hoje, 22:32
# https://sp.olx.com.br/vale-do-paraiba-e-litoral-norte/celulares/iphone-11-128-gb-novo-lacrado-1104333827
#
# iPhone XR
# R$ 2.700
# São José dos Campos, Vila Ema - DDD 12
# Hoje, 22:32
# ...

# %%
len(lista_de_produtos)
# Out:
# 2443
